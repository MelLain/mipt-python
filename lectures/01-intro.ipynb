# %% [markdown]
# # Практикум по программированию на языке Python
#
# ## <font color='lilac'>Занятие 1: введение в Python, встроенные типы данных, модель памяти</font>
#
# #### Мурат Апишев (mel-lain@yandex.ru)
# #### Москва, 2025

# %% [markdown]
# ### <font color='lilac'>Правила курса</font>
#
# - Курс будет состоять из примерно 10 тем, разбитых на 3 логических блока
# - Будет 4 базовых и одно дополнительное домашние задания на 2 недели каждое
# - Для получения зачета обязательно выполнение всех базовых заданий не менее чем на половину возможных баллов
# - Дополнительное задание может быть выдано индивидуально при нехватке баллов (оно сложнее базовых)
# - Списывать (в т.ч. из LLM) и пропускать дедлайны нельзя
# - Зачёт выставляется по результатам выполнения заданий (точные баллы будут позже) и очного собеседования

# %% [markdown]
# ### <font color='lilac'>Зачем изучать Python?</font>
#
# Несколько смежных вопросов:
#
# - зачем DS уметь программировать?
# - зачем DS уметь программировать хорошо?
# - зачем учиться программировать хорошо на Python?

# %% [markdown]
# ### <font color='lilac'>Python - хороший язык, потому что он</font>
#
# - _читабельный и согласованный_ - его легко понимать и сопровождать
# - _высокоуровневый_ - код лаконичнее, чем у большинства других языков
# - _универсальный_ - вести успешную разработку на Python можно почти в любой IT-области
# - _мультипарадигмальный_ - процедурный, объектно-ориентированный, функциональный
# - _кроссплатформенный_ - легко разрабатывать и запускать код под любой популярной ОС
# - _легко интегрируемый_ - активно используется в связке с другими языками
# - _прост в изучении_ - сложно найти язык с более низким порогом входа
# - _богатый и активно развивающийся_ - open-source + большое сообщество способны на многое

# %% [markdown]
# ### <font color='lilac'>Где писать код на Python</font>
#
# - в любом удобном текстовом редакторе
# - в Jupyter Notebook
# - в специализированной IDE (например, PyCharm)
#
# Обычно файлы с кодом на Python имеют расширение `.py`

# %% [markdown]
# ### <font color='lilac'>Где исполнять код на Python</font>
#
# - Python - скриптовый язык, исполняемый интерпретатором
# - Стандартная версия интепретатора - CPython, будем пользоваться ей
# - Можно установить интерпретатор + стандартные библиотеки языка (https://www.python.org)
# - Удобнее поставить распространённый дистрибутив Anaconda (https://www.anaconda.com/download)
# - В комплекте идут дополнительно популярные библиотеки и Jupyter Notebook
#
#
# __При установке обратите внимание, что в курсе мы ориентируемся на Python версии 3.7__

# %% [markdown]
# ### <font color='lilac'>Как можно запускать код на Python</font>
#
# - Запускаем интерпретатор в терминале и напрямую пишем команды
# - Пишем код в файле и запускаем командой `python <имя файла>`
# - Создаём файл Jupyter Notebook и запускаем код в его ячейках

# %% [markdown]
# ### <font color='lilac'>Классическая первая программа</font>

# %%
print('Hello world!')
# Out:
# Hello world!

# %% [markdown]
# - не требуется специфических объявлений точки входа программы (main в C++) - код запускается с первой строки файла/ячейки
# - `print` - стандартная функция языка, печатающая аргументы в стандартный поток вывода

# %% [markdown]
# ### <font color='lilac'>Операторы присваивания</font>

# %%
a = 5
print(a)
# Out:
# 5

# %%
a, b, c = 5, 6, 7
print(a, b, c)
# Out:
# 5 6 7

# %% [markdown]
# ### <font color='lilac'>Ввод с клавиатуры</font>

# %%
f_name = input('Enter your first name:')
l_name = input('Enter your last name:')
print(f_name, l_name)
# Out:
# Enter your first name: M
# Enter your last name: A
# M A

# %% [markdown]
# ### <font color='lilac'>Выполнение кода на Python в виде строки</font>

# %%
eval('123 + 45')
# Out:
# 168

# %%
exec(
'''
a = 12
b = 3
print(a ** b)
''')
print(a, b)
# Out:
# 1728
# 12 3

# %% [markdown]
# - `eval` позволяет вычислить выражение и возвращает его результат (чистая функция)
# - `exec` позволяет запустить любой фрагмент кода на python (пример: ячейки Jupyter Notebook)

# %% [markdown]
# ### <font color='lilac'>Объекты и переменные</font>

# %%
4
# Out:
# 4

# %% [markdown]
# - создан объект типа `int`, который содержит значение 4
# - поскольку на этот объект нет ссылок, он уничтожается после создания и печати

# %%
a = 5

# %% [markdown]
# - создан объект типа `int`, в котором содержится значение 5
# - затем создана переменная с именем `a`, которая ссылается на этот объект

# %%
del a

# %% [markdown]
# - переменная `a` принудительно удалена
# - объект, на который она ссылалась, тоже был удалён, поскольку больше на него нет ссылок

# %% [markdown]
# ### <font color='lilac'>Объекты и переменные</font>

# %%
a = 5
b = a

# %% [markdown]
# - создан объект типа `int`, в котором содержится значение 5
# - затем создана переменная с именем `a`, которая ссылается на этот объект
# - создана переменная `b`, которая указывает на тот же объект типа `int`

# %%
a = a + 1  # equals to a += 1
print(b)
# Out:
# 5

# %% [markdown]
# - выражение `a = a + 1` создаёт новый объект типа `int`, равный 6
# - переменная `a` начинает ссылаться на него и больше не связана с объектом, равным 5
# - `b` продолжает ссылаться на него

# %% [markdown]
# ### <font color='lilac'>Объекты и переменные в Python</font>
#
# - Переменные $\ne$ объекты
# - Объект - это сущность, созданная и используемая в коде
# - Объектами являются числа, строки, контейнеры, классы, функции и т.п.
# - Переменная - это именованная ссылка на объект
# - У одного объекта может быть много ссылок-переменных
# - Объекты являются строго типизированными, ссылки - нет

# %% [markdown]
# ### <font color='lilac'>Основные встроенные типы данных</font>
#
# - _логический, числовые, None_
# - _строковые_
# - _контейнерные: списки, словари, кортежи, множества_
# - _файловый_
# - _прочие: функции, классы, модули, сами типы_
#
# Python -
# - динамически типизируемый (сам следит за выводом типов)
# - язык со строгой типизацией (объект заданного типа допускает только связанные с ним операции)
#
# __Тип объекта можно получить с помощью функции type__

# %% [markdown]
# ### <font color='lilac'>Логический тип</font>

# %%
True or False
# Out:
# True

# %%
True or destroy_the_world()
# Out:
# True

# %%
True and (False or True)
# Out:
# True

# %%
bool()
# Out:
# False

# %%
type(True)
# Out:
# bool

# %% [markdown]
# ### <font color='lilac'>Целые числа</font>
#
# В Python тип `int` поддерживает бесконечно большие числа

# %%
2 + 5
# Out:
# 7

# %%
4 // 3
# Out:
# 1

# %%
4 % 3
# Out:
# 1

# %%
2 ** 100
# Out:
# 1267650600228229401496703205376

# %%
type(1)
# Out:
# int

# %% [markdown]
# ### <font color='lilac'>Литералы типа int</font>

# %%
100, -20, 0  # decimal
# Out:
# (100, -20, 0)

# %%
0b11, 0B10  # binary
# Out:
# (3, 2)

# %%
0o11, 0O11  # octal
# Out:
# (9, 9)

# %%
0x90A, 0X9F # hexadecimal
# Out:
# (2314, 159)

# %%
bin(1000), oct(1000), hex(1000)
# Out:
# ('0b1111101000', '0o1750', '0x3e8')

# %% [markdown]
# ### <font color='lilac'>Побитовые операции</font>
#
# Работаем с целыми числами как с битовыми массивами

# %%
1 << 2  # 001b -> 100b == 4d
# Out:
# 4

# %%
7 >> 1  # 111b -> 011b == 3d
# Out:
# 3

# %%
1 & 2  # 01b || 10b == 00b
# Out:
# 0

# %%
1 | 2  # 01b || 10b == 11b == 3d
# Out:
# 3

# %% [markdown]
# ### <font color='lilac'>Числа с плавающей точкой</font>
#
# Вещественные числа в Python - это тип `double` из C

# %%
1.0 + 2
# Out:
# 3.0

# %%
4 / 3
# Out:
# 1.3333333333333333

# %%
3 ** 2.5
# Out:
# 15.588457268119896

# %%
type(1.0)
# Out:
# float

# %%
type(float())
# Out:
# float

# %% [markdown]
# ### <font color='lilac'>Литералы числовых типов языка</font>
#
# - Вещественные:

# %%
1.3, 4., 1e+5, 1.0E+54
# Out:
# (1.3, 4.0, 100000.0, 1e+54)

# %% [markdown]
# - Комплексные:

# %%
3+4j, 2.0+1j, 5J
# Out:
# ((3+4j), (2+1j), 5j)

# %% [markdown]
# - Расширение для дробных чисел

# %%
import fractions
a = fractions.Fraction(1, 3 ** 1000000)
len(str(a.denominator))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[76], line 3
#       1 import fractions
#       2 a = fractions.Fraction(1, 3 ** 1000000)
# ----> 3 len(str(a.denominator))
#
# ValueError: Exceeds the limit (4300 digits) for integer string conversion; use sys.set_int_max_str_digits() to increase the limit

# %% [markdown]
# ### <font color='lilac'>Сравнение чисел</font>

# %%
x, y, z = 1, 2, 3

# %%
x < y < z
# Out:
# True

# %%
x < y >= z
# Out:
# False

# %%
x < y != z
# Out:
# True

# %% [markdown]
# ### <font color='lilac'>Округление вещественных чисел</font>

# %%
11.0 // 3.0  # remove remainder
# Out:
# 3.0

# %%
import math

print(math.trunc(4.7))  # move to zero
print(math.trunc(-4.7))
# Out:
# 4
# -4

# %%
print(math.floor(4.7))  # move to lowest integer
print(math.floor(-4.7))
# Out:
# 4
# -5

# %%
print(round(4.3))  # standart round
print(round(-4.7))
# Out:
# 4
# -5

# %% [markdown]
# ### <font color='lilac'>Полезные встроенные функции для чисел</font>

# %%
pow(2, 4) == 2 ** 4
# Out:
# True

# %%
abs(-2)
# Out:
# 2

# %%
sum((1, 2, 3))
# Out:
# 6

# %%
min(1, 2, -7, 44)
# Out:
# -7

# %%
import math
print(math.sqrt(4))
print(math.sin(8))
# Out:
# 2.0
# 0.9893582466233818

# %% [markdown]
# ### <font color='lilac'>Тип None</font>

# %%
None == None
# Out:
# True

# %%
None or True
# Out:
# True

# %%
type(None)
# Out:
# NoneType

# %%
5 * None  # strong typing
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[93], line 1
# ----> 1 5 * None  # strong typing
#
# TypeError: unsupported operand type(s) for *: 'int' and 'NoneType'

# %% [markdown]
# ### <font color='lilac'>Строки</font>

# %%
s = 'qwerty'
type(s)

# %%
len(s)  # built-in function to get sequence length

# %%
s[0]  # make a copy of element

# %%
s[-1]  # make a copy of element

# %%
s[0: 3]  # make a copy of elements from 0 to 3 excluding

# %%
s + '-add-on'

# %% [markdown]
# ### <font color='lilac'>Подробнее об индексировани и срезах</font>

# %%
s = 'qwerty'
s[0]

# %%
s[0: 10]

# %%
s[slice(1, 3)]

# %%
s[:10:2]  # QwErTy____

# %%
s[::-1]

# %% [markdown]
# ### <font color='lilac'>Операции над строками</font>

# %%
s + 5  # strong typing

# %%
s * 5  # strong typing

# %%
s[0] = 'a'  # str type is immutable

# %% [markdown]
# ### <font color='lilac'>Операции над строками</font>

# %%
s = 'Qwe{}'.format('rty')
s

# %%
print(s.find('w'), s.find('9'))

# %%
s.split('r')

# %%
'-'.join(['New', 'York'])

# %%
s.replace('ty', 'TY')

# %%
s[0].isupper()

# %% [markdown]
# ### <font color='lilac'>Операции над строками</font>
#
# Две новые простые операции были добавлены в Python 3.9:

# %%
'prefix_string'.removeprefix('prefix_')

# %%
'string_suffix'.removesuffix('_suffix')

# %% [markdown]
# ### <font color='lilac'>Как ещё можно задавать строки</font>

# %%
'qwe\'rty'

# %%
"qwe'rty"

# %%
'''qwe'rty'''

# %%
'qwe\0rty'  # print hex code in '\xNN' format for non-printable characters

# %%
'qwe\nrty'

# %%
print('qwe\nrty')  # we'll discuss difference between __repr__ and __str__ further

# %% [markdown]
# ### <font color='lilac'>Форматирование строк</font>
#
# В Python есть похожих способа форматирования - выражение и метод

# %%
'x = %d, y = %f' % (10.5, 11)

# %%
'x = %o, y = %E' % (8, 1.0 / 3)  # octal format, exponential + upper case

# %%
'x = %10.2f' % (1.0 / 3)  # min width and precision

# %%
# add leading zeros if len < min width
s = '''
x = %(value_1)010.2f
x = %(value_2)010.2f
''' % ({'value_1': 10000, 'value_2': 0.12345})

print(s)  # __str__
s         # __repr__

# %% [markdown]
# ### <font color='lilac'>Форматирование строк</font>

# %%
'x = {}, y = {}'.format(10, 20)

# %%
'x = {1}, y = {0}'.format(10, 20)

# %%
f'x = {10}, y = {20}'

# %%
'x = {val_1:f}, y = {val_2:010.2f}'.format(val_1=10, val_2=10)

# %%
import sys
'platform: {sys_var.platform}'.format(sys_var=sys)

# %% [markdown]
# ### <font color='lilac'>Оператор присваивания в форматных строках</font>
#
# Синтаксический сахар, добавленый в версии Python 3.8:

# %%
from datetime import date
from math import cos, radians

user = 'eric_idle'
member_since = date(1975, 7, 31)

f'{user=} {member_since=}'

# %% [markdown]
# Можно форматировать вывод:

# %%
delta = date.today() - member_since
f'{user=!s}  {delta.days=:d}'

# %% [markdown]
# Можно вставлять вычисления и выводить как результат, так и вычисляющий код:

# %%
theta = 4
f'{theta=}  {cos(radians(theta))=:.3f}'

# %% [markdown]
# ### <font color='lilac'>Строка как набор байтов</font>

# %%
b = bytearray(b'qwerty')
type(b)

# %%
b[1] = ord('a')
b

# %% [markdown]
# - `bytearray` - массив байтов, в который можно записывать номера 8-битных символов
# - в отличие от `str`, объекты этого типа являются изменяемыми
# - функция `ord` возвращает по символу его номер в таблице ASCII

# %% [markdown]
# ### <font color='lilac'>Контейнерные типы: списки

# %%
lst = [1, None, 'qwerty']
list([1, None, 'qwerty']) == lst  # list() gets any iterable object as input

# %%
lst[0] = [10, 20]
lst

# %% [markdown]
# - список - более общий аналог массива (не путать со структурой данных "список")
# - элементы могут быть произвольного типа (в т.ч. и ссылками)
# - сам список является изменяемым типом

# %% [markdown]
# ### <font color='lilac'>Списки</font>

# %%
len(lst)

# %%
type(lst)

# %%
lst[-1]

# %%
lst[: 100]  # slice bounds can be exceed real ones

# %%
lst[5]

# %% [markdown]
# ### <font color='lilac'>Операции над списками</font>

# %%
lst = [1, 2, 3]
lst.append(4)
lst

# %%
print(lst.pop(), lst)

# %%
lst.sort(reverse=True)  # equals to lst.reverse()
lst

# %%
lst * 2

# %%
lst + list('abc')

# %% [markdown]
# ### <font color='lilac'>Списковые включения и генераторы списков</font>

# %%
[x ** 2 for x in [1, 2, 3]]  # list comprehension

# %%
lst = [x ** 2 for x in [1, 2, 3] if x > 1]
print(type(lst))

for _ in [1, 2]:  # _ means value we really don't need
    for e in lst:
        print(e)

# %%
lst = (x ** 2 for x in [1, 2, 3] if x > 1)  # list generator
print(type(lst))

for _ in [1, 2]:
    for e in lst:
        print(e)

# %% [markdown]
# ### <font color='lilac'>Снова про объекты и переменные</font>

# %%
a = [2]
b = a
a += [1]
print(b)

# %% [markdown]
# - список - изменяемый объект, создание новой ссылки не приводит к появлению нового объекта
# - есть две переменные, указывающие на один и тот же список

# %%
del a
print(b)

# %% [markdown]
# - удаление `a` не приводит у удалению списка, поскольку на него ещё ссылается `b`

# %% [markdown]
# ### <font color='lilac'>Копирование изменяемых объектов</font>

# %%
a = [1, 2, 3]
b = a[:]
b.append(4)
print(a)

# %%
a = [1, 2, 3]
b = a.copy()
b.append(4)
print(a)

# %% [markdown]
# ### <font color='lilac'>Копирование вложенных изменяемых объектов</font>

# %%
a = [['a', 'b', 'c'], 2, 3]
b = a.copy()
b[0].append('d')
print(a)
print(b)

# %%
import copy

a = [['a', 'b', 'c'], 2, 3]
b = copy.deepcopy(a)
b[0].append('d')
print(a)
print(b)

# %% [markdown]
# ### <font color='lilac'>Контейнерные типы: словари</font>
#
# - словарь (`dict`) - это ассоциативный массив (отображение), т.е. набор пар "ключ-значение"
# - словарь поддерживает возможность быстро искать значение по ключу
# - в Python словари реализованы на основе хэш-таблиц (сложность поиска O(1))
# - словари также являются изменяемым типом данных
# - значения могут иметь произвольный тип
# - ключи - произвольный неизменяемый тип

# %% [markdown]
# ### <font color='lilac'>Словари</font>

# %%
type(dict()), type({})

# %%
# simple creation of nested structures!
d = {'1': 1, 's': 2, None: [1, {None: True}]}
d

# %%
d['s'] = 'two'
d

# %%
del d['1']  # remove object
print(d)

# %%
d2 = {('s', 3), ('a', 'b')}

# %% [markdown]
# ### <font color='lilac'>Операции над словарями</font>

# %%
d = dict.fromkeys(list('abcccc'))
d

# %%
for k in d.keys():  # view object
    d[k] = ord(k)
d

# %%
for k, v in d.items():  # view object
    print(k, v)

# %%
D = dict(a=ord('a'), b=ord('b'), c=ord('c'))
d == D

# %%
d.update(d2)
d

# %% [markdown]
# ### <font color='lilac'>Операции над словарями</font>
#
# Новый оператор слияния словарей был введен начиная с Python 3.9:

# %%
d_1, d_2 = {1: 'a', 2: 'b'}, {3: 'c', 4: 'd'}
d_1 | d_2

# %%
d_2 = {1: 'c'}
d_1 | d_2

# %%
#d_1 | [(3, 'c'), (4, 'd')] -> TypeError: unsupported operand type(s) for |: 'dict' and 'list'

# %%
d_1, d_2 = {1: 'a', 2: 'b'}, {3: 'c', 4: 'd'}
d_1 |= d_2
d_1

# %%
d_1 = {1: 'a', 2: 'b'}
d_1 |= [(3, 'c'), (4, 'd')]
d_1

# %% [markdown]
# ### <font color='lilac'>Контейнерные типы: кортежи</font>
#
# - очень похожи на списки, но являются неизменяемыми

# %%
type(()), type(tuple())

# %%
(1, 2, 'str', 4.0, None)
# Out:
# (1, 2, 'str', 4.0, None)

# %%
(1, 2) + (3.0, 6, None)
# Out:
# (1, 2, 3.0, 6, None)

# %%
tpl = tuple([1, 2, 3])
tpl[2]
# Out:
# 3

# %% [markdown]
# ### <font color='lilac'>Контейнерные типы: множества</font>
#
# - Как и словари, основаны на хэш-таблицах
# - Элементы должны быть неизменяемыми

# %%
type(set()), type({1}), type({})  # Empty '{}' is a dict, not a set!
# Out:
# (set, set, dict)

# %%
{1, 2, 3, 3, 2, 1, 'set', 'a'}
# Out:
# {1, 2, 3, 'a', 'set'}

# %%
s = {1, 2, 3}
s.add(4)
s
# Out:
# {1, 2, 3, 4}

# %%
s1, s2 = {1, 2, 3}, set([3, 4, 5])

print('{}\t{}\t{}\t{}'.format(s1 - s2, s1 | s2, s1 & s2, s1 < s2))
# Out:
# {1, 2}	{1, 2, 3, 4, 5}	{3}	False

# %% [markdown]
# ### <font color='lilac'>Операции над множествами</font>

# %%
A, B = set('abc'), {'a', 'c', 'd'}

# %%
A - B  # minus: in A and not in B (== A.difference(B))
# Out:
# {'b'}

# %%
A | B  # union: in A or in B (== A.union(B))
# Out:
# {'a', 'b', 'c', 'd'}

# %%
A & B  # intersection: in A and in B (== A.intersection(B))
# Out:
# {'a', 'c'}

# %%
A ^ B  # sym diff: (in A and not in B) and via versa (== A.symmetric_difference(B))
# Out:
# {'b', 'd'}

# %% [markdown]
# ### <font color='lilac'>Операции над множествами</font>

# %%
A.add('e')
A
# Out:
# {'a', 'b', 'c', 'e'}

# %%
A.update(B)
A
# Out:
# {'a', 'b', 'c', 'd', 'e'}

# %%
A.remove('a')
A
# Out:
# {'b', 'c', 'd', 'e'}

# %%
'a' in A
# Out:
# False

# %%
{'a', 'b'} < A  # is subset (== {'a', 'b'}.issubset(A))
# Out:
# False

# %% [markdown]
# ### <font color='lilac'>Файловый тип</font>

# %%
fin = open('some_file.txt', 'r')  # 'r' can be avoided
print(fin.read())
fin.close()
fin.closed
# Out:
# some
# content
# True

# %%
fin = open('some_file.txt', 'r')  # 'r' can be avoided

# strip removes blank and special characters from edges
lines = [line.strip() for line in fin.readlines()]

print(' '.join(lines))
fin.close()
fin.closed
# Out:
# some content
# True

# %% [markdown]
# ### <font color='lilac'>Файловый менеджер контекста</font>

# %%
fin = open('some_file.txt', 'r')  # 'r' can be avoided
print(fin.read(), 0/0)
fin.close()
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[114], line 2
#       1 fin = open('some_file.txt', 'r')  # 'r' can be avoided
# ----> 2 print(fin.read(), 0/0)
#       3 fin.close()
#
# ZeroDivisionError: division by zero

# %%
fin.closed
# Out:
# False

# %% [markdown]
# ### <font color='lilac'>Файловый менеджер контекста</font>

# %%
with open('some_file.txt', 'r') as fin:
    print(fin.read(), 0/0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[116], line 2
#       1 with open('some_file.txt', 'r') as fin:
# ----> 2     print(fin.read(), 0/0)
#
# ZeroDivisionError: division by zero

# %%
fin.closed
# Out:
# True

# %% [markdown]
# ### <font color='lilac'>Запись в файл</font>
#
# - отступы используются для обозначения операторных блоков (вместо фигурных скобок в C++)

# %%
with open('some_file.txt', 'a') as fout:
    fout.write('additional string')

# %%
with open('some_file.txt', 'r') as fin:
    print(fin.read())
# Out:
# some
# content
# additional string

# %%
with open('some_file.txt', 'w') as fout:
    fout.write('new\ncontent')

# %%
with open('some_file.txt', 'r') as fin:
    print(fin.read())
# Out:
# new
# content

# %% [markdown]
# ### <font color='lilac'>Содержимое файлов как массив байтов</font>
#
# Полезно при работе с сериализаторами

# %%
s = bytearray('строка', 'utf-8')
with open('tmp.bin', 'wb') as fout:
    fout.write(s)

# %%
with open('tmp.bin', 'r') as fin:
    print(list(fin.read()))
# Out:
# ['с', 'т', 'р', 'о', 'к', 'а']

# %%
with open('tmp.bin', 'rb') as fin:
    print(list(fin.read()))
# Out:
# [209, 129, 209, 130, 209, 128, 208, 190, 208, 186, 208, 176]

# %%
len('з'.encode('utf-8'))
# Out:
# 2

# %% [markdown]
# ### <font color='lilac'>Условный оператор if</font>

# %%
if 3 % 3 == 0:
    print('success')
# Out:
# success

# %%
a = 5
if a == 2:
    print(2)
elif a == 4:
    print(4)
else:
    print(a)
# Out:
# 5

# %%
print(a if a > 5 else 2.5)  # ternary operator
# Out:
# 2.5

# %% [markdown]
# ### <font color='lilac'>Оператор цикла while</font>

# %%
a = 5
while a > 4:
    print('Current a: {}'.format(a))
    a -= 1
# Out:
# Current a: 5

# %%
while True:  # infinity loop
    pass  # in Python 3 the equal statement is '...'
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[130], line 1
# ----> 1 while True:  # infinity loop
#       2     pass  # in Python 3 the equal statement is '...'
#
# KeyboardInterrupt:

# %%
a = 6
while a > 2:
    a -= 1
    if a == 5: continue
    if a == 3: break
    print(a)
else:
    print('else')
# Out:
# 4

# %% [markdown]
# - `pass` - оператор пустого действия
# - `continue` - досрочный переход на следующую итерацию цикла
# - `break` - досрочный выход из цикла
# - `else` - обозначает секцию, которая выполняется, если цикл был завершён не по `break`

# %% [markdown]
# ### <font color='lilac'>Оператор цикла for</font>
#
# - в отличие от C/C++, в Python чаще всего используются range-based for-циклы
# - классические циклы по индексам так же доступны, но при прочих равных менее предпочтительны

# %%
lst = ['a', 'b', 'c']
for element in lst:  # range-based for
    print(element)
# Out:
# a
# b
# c

# %%
for index in range(len(lst)):  # index-based for
    print(lst[index])
# Out:
# a
# b
# c

# %% [markdown]
# - функция `range` создаёт генератор, позволяющий итерироваться по последовательности чисел с заданными границами и шагом

# %% [markdown]
# ### <font color='lilac'>Оператор цикла for</font>

# %%
for x, y in [(1, 'a'), [2, 'b']]:
    print(x, y)
else:
    print('For-loop ended without break!')
# Out:
# 1 a
# 2 b
# For-loop ended without break!

# %%
for x, y, z in [[1, 2, 3], ['a', 'b', 'c'], [True, False, None]]:
    if isinstance(x, int):
        continue
    print(x, y, z)
# Out:
# a b c

# %% [markdown]
# - `isinstance` - функция языка, позволяющая проверить принадлженость объекта типу (учитывает иерархию наследования типов)

# %% [markdown]
# ### <font color='lilac'>Оператор walrus</font>
#
# - "Моржовый" оператор был добавлен в Python начиная с версии 3.8
# - Он является присваивающим _выражением_, т.е., в отличие от _оператора_ присваивания, он возвращает присвоенное значение

# %%
if (n := len('test')) > 3:
    print(f'String is too long ({n})')
# Out:
# String is too long (4)

# %% [markdown]
# Иногда он может уменьшить объем вычислений:

# %%
[x ** 2 for x in range(10) if x ** 2 % 2 == 0]
# Out:
# [0, 4, 16, 36, 64]

# %%
[y for x in range(10) if (y := x ** 2) % 2 == 0]
# Out:
# [0, 4, 16, 36, 64]

# %% [markdown]
# ### <font color='lilac'>Атрибуты объекта</font>
#
# - любой объект в Python имеет атрибуты: набор полей и методов, определяющих свойства объекта и способы работы с ним
# - атрибуты можно читать, устанавливать и менять
# - список всех атрибутов получается с помощью встроенной функции `dir`

# %%
print(len(dir(5)))
print(dir(5)[: 4])
# Out:
# 74
# ['__abs__', '__add__', '__and__', '__bool__']

# %%
a = 5
a.__and__(0)  # exactly the same as 'a and 0'
# Out:
# 0

# %% [markdown]
# ### <font color='lilac'>Как правильно называть переменные</font>
#
# - `regular_variable`
# - `ClassName`
# - `SOME_CONSTANT_10`
# - `_private_class_field_or_method`
# - `__avoid_overriding_of_this_field_or_method_in_childrens`
# - `__magic_method__` or `__special_field__`

# %% [markdown]
# __Не используйте переменные с unicode-символами__:
# - `плохое_имя_для_переменной`

# %% [markdown]
# ### <font color='lilac'>Модули</font>
#
# - любой файл на Python представляет собой модуль
# - импорт модуля вызовет выполнение содержащегося в нём кода

# %%
with open('test_module.py', 'w') as fout:
    fout.write('print(10)\n')
    fout.write('def new_print(a):\n\tprint(a)\n')

# %% [markdown]
# - создали текстовый файл и записали в него оператор печати и определение функции
# - ключевое слово `def` используется для определения функций и классов (не единственный способ)

# %%
import test_module
# Out:
# 10

# %% [markdown]
# - импортируем модуль, операторы выполнятся
#
# __В стандартной библиотеке языка есть много полезных модулей - надо пользоваться__

# %% [markdown]
# ### <font color='lilac'>Пространства имён модулей</font>

# %%
new_print(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[143], line 1
# ----> 1 new_print(5)
#
# NameError: name 'new_print' is not defined

# %%
test_module.new_print(5)
# Out:
# 5

# %%
from test_module import new_print
new_print(5)
# Out:
# 5

# %% [markdown]
# ### <font color='lilac'>Повторная загрузка модуля</font>
#
# - если модуль был один раз загружен (исполнен), второй импорт ничего не произведёт
# - это верно даже в том случае, если модуль был изменён после импорта

# %%
import test_module  # no any output!

# %% [markdown]
# - но модуль можно перезагрузить принудительно

# %%
from importlib import reload
reload(test_module)
# Out:
# 10
# <module 'test_module' from '/Users/msk-hq-nb-2930/Work/mipt-python/lectures/test_module.py'>

# %% [markdown]
# ### <font color='lilac'>Компиляция кода на Python</font>
#
# - Код на языке Python перед выполнением транслируется в байт-код
# - Это байт-код выполняется виртуальной машиной языка, в ходе чего он переводится в машинные команды
# - Генерация байт-кода при выполнении кода скрипта выполняется на лету
# - Однако в случае импортирования кода из модуля байт-код этого модуля сохраняется в файлы с расширением `.pyc`
# - В дальнейшем это позволяет ускорить загрузку модуля (но не скорость выполнения!)
# - Необходимость перегенерации файла `.pyc` определяется по времени последнего изменения этого файла и его исходника
# - Хорошей практикой является игнорирование этих файлов и автоматическая перегенерация при каждом запуске в новом окружении
# - Помимо файлов `.pyc` генерироваться могут файлы `.pyo` (запуск с оптимизацией) и `.pyd` (файл типа dll в ОС Windows)

# %% [markdown]
# ### <font color='lilac'>Модуль collections</font>
#
# Стандартная задача: подсчёт числа элементов

# %%
s = 'GDJKFHGKJXBZFVJHBJZBXXXXXXXXXXXXXXXXXXXHFG'

# %%
d = {}
for element in s:
    if not element in d:
        d[element] = 0
    d[element] += 1

result = ''
for k, v in d.items():
    result += f'({k}: {v}) '
print(result.strip())
# Out:
# (G: 3) (D: 1) (J: 4) (K: 2) (F: 3) (H: 3) (X: 20) (B: 3) (Z: 2) (V: 1)

# %%
from collections import Counter

for k, v in Counter(s).items():
    print(f'({k}: {v}) ', end='')  # print can end not only with '\n'
print()
# Out:
# (G: 3) (D: 1) (J: 4) (K: 2) (F: 3) (H: 3) (X: 20) (B: 3) (Z: 2) (V: 1)

# %% [markdown]
# ### <font color='lilac'>Модуль os</font>
#
# `os` содержит разнообразные функции и библиотеки для широкого круга задач:
# - работа с переменными окружения
# - работа с процессами
# - работа с файловой системой
# - работы с путями в файловой системе (библиотека `os.path`)

# %%
import os

len(os.listdir('.'))
# Out:
# 10

# %%
os.mkdir('temp')
os.rmdir('temp')

os.mkdir('temp')
os.mkdir('temp/temp')
#os.rmdir('temp') -> OSError: [Errno 39] Directory not empty: 'temp'

# %%
import shutil

shutil.rmtree('temp')

# %% [markdown]
# ### <font color='lilac'>Библиотека os.path</font>

# %%
print(os.path.exists('01-intro.ipynb'))
print(os.path.isfile('01-intro.ipynb'))
print(os.path.isdir('01-intro.ipynb'))
# Out:
# True
# True
# False

# %%
addr = os.path.dirname(os.path.abspath('01-intro.ipynb'))
print(addr)
# Out:
# /Users/msk-hq-nb-2930/Work/mipt-python/lectures

# %%
os.path.join(*addr.split('/'))  # f(*[a, b, c]) -> f(a, b, c)
# Out:
# 'Users/msk-hq-nb-2930/Work/mipt-python/lectures'

# %% [markdown]
# ### <font color='lilac'>pathlib - более удобный модуль для работы с файловой системой</font>
#
# - До Python 3.4 работа с ФС производилась с помощью `os` и `glob`
# - Теперь удобнее и нагляднее пользоваться модулем `pathlib`:

# %%
os.makedirs(os.path.join('temp', 'temp'), exist_ok=True)
os.rename('temp', 'new_temp')
shutil.rmtree('new_temp')

# %%
from pathlib import Path

Path('temp/temp').mkdir(parents=True, exist_ok=True)
Path('temp').rename('new_temp')
shutil.rmtree('new_temp')

# %% [markdown]
# - Вложенные вызовы тяжелее читать, чем последовательные
# - Модуль `shutil` все ещё необходим для удаления непустых директорий, перемещения и копирования

# %% [markdown]
# ### <font color='lilac'>pathlib: пример</font>
#
# Считывание текста из всех .ipynb-файлов в текущей директории с помощью `glob`:

# %%
from glob import glob

contents_1 = []
for filename in glob('*.ipynb', recursive=False):
    with open(filename) as fin:
        contents_1.append(fin.read())

# %% [markdown]
# И с помощью `pathlib`:

# %%
from pathlib import Path

contents_2 = [path.read_text() for path in Path.cwd().glob('*.ipynb')]

contents_1 == contents_2
# Out:
# True

# %% [markdown]
# ### <font color='lilac'>pathlib: итоговые замечания</font>
#
# - Использование `pathlib` улучшает качество кода и является рекомендованным стандартом для работы с ФС
# - `pathlib.Path` самостоятельно производит нормализацию путей в зависимости от ОС
# - Встроенные функции в Python 3.6 и выше, принимающие на вход строки-пути, умеют обрабатывать и объекты `Path`
# - `pathlib` уступает в скорости `os` в 2-4 раза, поэтому не подходит для фрагментов кода с очень интенсивной работой с ФС
#
#
# В новых версиях Python обеспечивается легкая взаимозаменяемость путей-строк и объектов `Path`:

# %%
path_str = os.path.join('temp', 'temp')
path_path = Path('temp/temp')

# %%
from os import fspath

a, b = fspath(path_str), fspath(path_path)
print(a, b, type(a), type(b))
# Out:
# temp/temp temp/temp <class 'str'> <class 'str'>

# %%
Path(path_str), Path(path_path)
# Out:
# (PosixPath('temp/temp'), PosixPath('temp/temp'))

# %% [markdown]
# ### <font color='lilac'>Модуль re для регулярных выражений</font>

# %%
import re

# %% [markdown]
# - `[]` - множество допустимых символов
# - `-` - обозначает диапазон
# - `*` - любое число повторений (в т.ч. 0)

# %%
eng_letters = re.compile('[a-zA-Z]*')

print(eng_letters.match(''))
print(eng_letters.match('qwerty'))
print(eng_letters.match('йцукен'))
print(eng_letters.match('QWERTY'))
print(eng_letters.match('qweкен'))
# Out:
# <re.Match object; span=(0, 0), match=''>
# <re.Match object; span=(0, 6), match='qwerty'>
# <re.Match object; span=(0, 0), match=''>
# <re.Match object; span=(0, 6), match='QWERTY'>
# <re.Match object; span=(0, 3), match='qwe'>

# %% [markdown]
# ### <font color='lilac'>Регулярные выражения</font>

# %% [markdown]
# - Букву Ё прописываем отдельно, она вне диапазона
# - Как в обычных строках, спецсимволы вносим как обычные с помощью `\`
# - `+` - любое число повторений, но не менее одного

# %%
eng_letters = re.compile('[a-zA-Zа-яА-ЯёЁ\\-.@]+')

print(eng_letters.match(''))
print(eng_letters.match('йцукен'))
print(eng_letters.match('Ёжик'))
print(eng_letters.match('Фрекен-Бок'))
print(eng_letters.match('mail@ya.ru'))
# Out:
# None
# <re.Match object; span=(0, 6), match='йцукен'>
# <re.Match object; span=(0, 4), match='Ёжик'>
# <re.Match object; span=(0, 10), match='Фрекен-Бок'>
# <re.Match object; span=(0, 10), match='mail@ya.ru'>

# %% [markdown]
# ### <font color='lilac'>Регулярные выражения</font>
#
# - `^` - обозначает необходимость начала строки при совпадении
# - `$` - обозначает необходимость конца строки при совпадении
# - `{}` - после квадратных скобок позволяет ограничить количество вхождений символов

# %%
phone_pattern = re.compile('^(\\+[0-9]{1} ?\\(?[0-9]{3}\\)? ?[0-9]{7})+$')

print(phone_pattern.match('89167698275'))
print(phone_pattern.match('+7 (916) 7698275'))
print(phone_pattern.match('+7(916)7698275'))
# Out:
# None
# <re.Match object; span=(0, 16), match='+7 (916) 7698275'>
# <re.Match object; span=(0, 14), match='+7(916)7698275'>

# %%
email_pattern = re.compile('^[A-Za-z0-9\.\+_-]+@[A-Za-z0-9\._-]+\.[a-zA-Z]*$')

print(email_pattern.match('mel-lain@yandex.ru'))
print(email_pattern.match('mel&lain@yandex.ru'))
print(email_pattern.match('mel-lain@yandex'))
# Out:
# <re.Match object; span=(0, 18), match='mel-lain@yandex.ru'>
# None
# None
# <>:1: SyntaxWarning: invalid escape sequence '\.'
# <>:1: SyntaxWarning: invalid escape sequence '\.'
# /var/folders/r2/563zpwbs3215hdfprj61qz880000gn/T/ipykernel_70517/2520189013.py:1: SyntaxWarning: invalid escape sequence '\.'
#   email_pattern = re.compile('^[A-Za-z0-9\.\+_-]+@[A-Za-z0-9\._-]+\.[a-zA-Z]*$')

# %% [markdown]
# ### <font color='lilac'>Регулярные выражения</font>

# %%
email_pattern = re.compile('[A-Za-z0-9\.\+_-]+@[A-Za-z0-9\._-]+\.[a-zA-Z]*')

print(email_pattern.match('mel-lain@yandex.ru mel-lain@yandex.ru'))
email_pattern.findall('mel-lain@yandex.ru mel-lain@yandex.ru')
# Out:
# <re.Match object; span=(0, 18), match='mel-lain@yandex.ru'>
# <>:1: SyntaxWarning: invalid escape sequence '\.'
# <>:1: SyntaxWarning: invalid escape sequence '\.'
# /var/folders/r2/563zpwbs3215hdfprj61qz880000gn/T/ipykernel_70517/2430247187.py:1: SyntaxWarning: invalid escape sequence '\.'
#   email_pattern = re.compile('[A-Za-z0-9\.\+_-]+@[A-Za-z0-9\._-]+\.[a-zA-Z]*')
# ['mel-lain@yandex.ru', 'mel-lain@yandex.ru']

# %% [markdown]
# Вместо конкретных символов можно использовать общие обозначения:
#
# - `\s` - один пробел
# - `\S` - один не пробел
# - `\w` - один alpha-numeric символ

# %%
re.split('\w', '&а%б!7#в*')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\w'
# <>:1: SyntaxWarning: invalid escape sequence '\w'
# /var/folders/r2/563zpwbs3215hdfprj61qz880000gn/T/ipykernel_70517/3240456138.py:1: SyntaxWarning: invalid escape sequence '\w'
#   re.split('\w', '&а%б!7#в*')
# ['&', '%', '!', '#', '*']

# %% [markdown]
# ### <font color='lilac'>Идентификатор объекта</font>
#
# - у каждого объекта в Python есть целочисленный идентификатор
# - на время жизни объекта он является уникальным
# - получить идентификатор объекта можно с помощью функции `id`

# %%
a = 10
b = 12
print(id(a), id(b))
# Out:
# 4385623912 4385623976

# %% [markdown]
# - идентификатор зависит от реализации, это может быть адрес в памяти
# - у одинаковых константных объектов этот идентификатор всегда одинаковый

# %%
a, b = 10, 10
c, d = 12, 12
print(id(a), id(b), '\n')
print(id(c), id(d))
# Out:
# 4385623912 4385623912
#
# 4385623976 4385623976

# %% [markdown]
# ### <font color='lilac'>Идентификатор константного объекта</font>
#
# - таким образом, одинаковые константы хранятся в единственном экземпляре
# - Python делает так для экономии памяти
# - типы в Python тоже являются объектами

# %%
print(id(type(12)), id(type(5)), id(int), '\n')
print(id(None), id(type(None)))
# Out:
# 4384741384 4384741384 4384741384
#
# 4384759024 4384757840

# %% [markdown]
# - проверка равенства идентификаторов делается с помощью оператора `is`

# %%
a = None
print(a is None)
print(a == None)
# Out:
# True
# True

# %% [markdown]
# ### <font color='lilac'>Идентификатор изменяемого объекта</font>
#
# - два одинаковых списка не идентичны:

# %%
a = [1, 2, 3]
b = [1, 2, 3]
a is b
# Out:
# False

# %% [markdown]
# - две ссылки на один список идентичны:

# %%
c = a
a is c
# Out:
# True

# %% [markdown]
# - и все между собой, очевидно, равны:

# %%
a == b == c
# Out:
# True

# %% [markdown]
# ### <font color='lilac'>Почему на None надо проверять с помощью is</font>

# %%
# https://stackoverflow.com/questions/3257919/what-is-the-difference-between-is-none-and-none

class Foo:
    def __eq__(self,other):  # magic method: == operator
        return True

foo=Foo()

print(foo == None)

print(foo is None)
# Out:
# True
# False

# %% [markdown]
# - кроме того, проверка на идентичность в общем случае быстрее, чем на эквивалентность

# %% [markdown]
# ### <font color='lilac'>Стадии жизни объекта</font>
#
# - Создание объекта приводит к выделению фрагмента памяти
# - У каждого объекта есть счётчик ссылок
# - Каждое новая ссылающаяся переменная увеличивает этот счётчик на единицу
# - Ссылку можно удалить с помощью оператора `del`
# - Когда счётчик ссылок на объект становится равным 0, объект удаляется
# - Удаление и создание объектов может не приводит к изменениям памяти в некоторых случаях из-за кэширования (например 0 или None)
# - Но в общем случае память выделяется и освобождается

# %% [markdown]
# ### <font color='lilac'>Сборщик мусора</font>
#
# - Освобождение памяти производит сборщик мусора (Garbage Collector)
# - Памяти освобождается не моментально, а в некоторый недетерминированный момент
# - Одной из сложностей поиска объектов для удаления являются т.н. циклические ссылки

# %%
a = [None]
a[0] = a
del a

# %% [markdown]
# - Сборщик мусора умеет работать с такими случаями

# %% [markdown]
# ### <font color='lilac'>Полезные функции</font>

# %%
import gc
gc.collect()  # call collection immediately
# Out:
# 469

# %%
import sys
a = 1
print(sys.getrefcount(a))  # cached popular value
print(sys.getrefcount('some str'))  # 1 after creation, 1 temporary, 1 - ???
# Out:
# 4294967295
# 3

# %% [markdown]
# ### <font color='lilac'>Слабые ссылки</font>

# %% [markdown]
# - Иногда возникает необходимость вести учёт объектов только когда они используются где-нибудь ещё
# - Но само слежение уже создаёт ссылку, из-за которой объект будет оставаться в памяти
# - Слабые ссылки дают возможность вести учёт объекта без создания ссылок на них
# - Для этого используется модуль weakref
# - Классическое приложение - кэширование объектов, пересоздание которых является затратным
# - Слабые ссылки нельзя создавать на объекты базовых типов

# %% [markdown]
# ### <font color='lilac'>Слабые ссылки</font>

# %%
# http://old.pynsk.ru/posts/2015/Sep/19/tainstvo-standartnoi-biblioteki-slabye-ssylki-weakref/#.XkhkS9kueV4

import weakref, gc

class A:
    def __init__(self, value):
        self.value = value
    def __repr__(self):  # magic method: information for print
        return str(self.value)

a = A(10)  # create object and strong reference
d = weakref.WeakValueDictionary()  # dict with weak references

d['k'] = a
d['k']
# Out:
# 10

# %%
del a
gc.collect()
d['k']
# Out:
# 10

# %% [markdown]
# - при запуске из терминала получается вывод "KeyError: 'k'"
# - видимо, в ноутбуке создаются дополнительные неявные ссылки

# %% [markdown]
# ### <font color='lilac'>Проверка стиля кода</font>
#
# - Стандартным набором правил codestyle для Python является PEP8
# - Есть несколько инструментов для проверки кода на соответствию стиля: `pep8`, `pyflakes`, `flake8`, `Pylint`
# - В рамках курса в качестве линтера используется `flake8`
# - Установка модуля стандартная через `pip`, используется он как утилита с управляющими флагами:

# %%
import os, shutil
os.mkdir('tmp')
with open('temp.py', 'w') as fout:
    fout.write('\n'.join([
        'print(1111111111111111111111111111111111111111111111111111111111111111111)',
        'print(1111111111111111111111111111111111111111111111111111111111111111111)  # noqa: E501\n',
    ]))

with open(os.path.join('tmp', 'temp.py'), 'w') as fout:
    fout.write('''print(1111111111111111111111111111111111111111111111111111111111111111111)''')

# %%
# !flake8 . --extend-exclude=tmp --show-source --statistics --count --max-line-length=20
shutil.rmtree('tmp')
# Out:
# ./temp.py:1:21: E501 line too long (74 > 20 characters)
# print(1111111111111111111111111111111111111111111111111111111111111111111)
#                     ^
# ./test_module.py:2:1: E302 expected 2 blank lines, found 0
# def new_print(a):
# ^
# ./test_module.py:3:1: W191 indentation contains tabs
# 	print(a)
# ^
# 1     E302 expected 2 blank lines, found 0
# 1     E501 line too long (74 > 20 characters)
# 1     W191 indentation contains tabs
# 3
